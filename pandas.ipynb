# %%
file = open('data.csv','x')
file.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    sn    name  age         add
# 0   1     Ram   34   Kathmandu
# 1   2   Shyam   47   Bhaktapur
# 2   3  Naresh   16        Doti
# 3   4  Suresh   44    Dhangadi
# 4   5   Lakpa   47  Solukhumbu
# 5   6  Sabina   22     Chitwan

# %%
df.head()
# Out:
#    sn    name  age         add
# 0   1     Ram   34   Kathmandu
# 1   2   Shyam   47   Bhaktapur
# 2   3  Naresh   16        Doti
# 3   4  Suresh   44    Dhangadi
# 4   5   Lakpa   47  Solukhumbu

# %%
df.head(3)
# Out:
#    sn    name  age        add
# 0   1     Ram   34  Kathmandu
# 1   2   Shyam   47  Bhaktapur
# 2   3  Naresh   16       Doti

# %%
df.tail()
# Out:
#    sn    name  age         add
# 1   2   Shyam   47   Bhaktapur
# 2   3  Naresh   16        Doti
# 3   4  Suresh   44    Dhangadi
# 4   5   Lakpa   47  Solukhumbu
# 5   6  Sabina   22     Chitwan

# %%
df.tail(2)
# Out:
#    sn    name  age         add
# 4   5   Lakpa   47  Solukhumbu
# 5   6  Sabina   22     Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df
# Out:
#       name  age         add
# sn
# 1      Ram   34   Kathmandu
# 2    Shyam   47   Bhaktapur
# 3   Naresh   16        Doti
# 4   Suresh   44    Dhangadi
# 5    Lakpa   47  Solukhumbu
# 6   Sabina   22     Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn',usecols = ['sn','name','add'])
df
# Out:
#       name         add
# sn
# 1      Ram   Kathmandu
# 2    Shyam   Bhaktapur
# 3   Naresh        Doti
# 4   Suresh    Dhangadi
# 5    Lakpa  Solukhumbu
# 6   Sabina     Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:5,0:3]
# Out:
#       name  age         add
# sn
# 2    Shyam   47   Bhaktapur
# 3   Naresh   16        Doti
# 4   Suresh   44    Dhangadi
# 5    Lakpa   47  Solukhumbu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.loc[2:3]
# Out:
#       name  age        add
# sn
# 2    Shyam   47  Bhaktapur
# 3   Naresh   16       Doti

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df
# Out:
#         sn  age         add
# name
# Ram      1   34   Kathmandu
# Shyam    2   47   Bhaktapur
# Naresh   3   16        Doti
# Suresh   4   44    Dhangadi
# Lakpa    5   47  Solukhumbu
# Sabina   6   22     Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df.loc['Ram':'Lakpa']
# Out:
#         sn  age         add
# name
# Ram      1   34   Kathmandu
# Shyam    2   47   Bhaktapur
# Naresh   3   16        Doti
# Suresh   4   44    Dhangadi
# Lakpa    5   47  Solukhumbu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df['add']
# Out:
# name
# Ram        Kathmandu
# Shyam      Bhaktapur
# Naresh          Doti
# Suresh      Dhangadi
# Lakpa     Solukhumbu
# Sabina       Chitwan
# Name: add, dtype: object

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
list(df['add'])
# Out:
# ['Kathmandu', 'Bhaktapur', 'Doti', 'Dhangadi', 'Solukhumbu', 'Chitwan']

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df[df['add']=="Chitwan"]
# Out:
#         sn  age      add
# name
# Sabina   6   22  Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df[(df['add']=="Chitwan")&(df['age']<30)]
# Out:
#         sn  age      add
# name
# Sabina   6   22  Chitwan

# %%
data= {'name':['mahesh', 'naresh', 'suresh'], 
        'age': [5, 4, 4], 
        'add': ['3', '5', '5']}
df = pd.DataFrame(data)
df.to_csv('new_data.csv')
df
# Out:
#      name  age add
# 0  mahesh    5   3
# 1  naresh    4   5
# 2  suresh    4   5
